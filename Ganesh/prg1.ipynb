# %%
for x in range (1,100):
    if x%7 == 0 and x%9!= 0:
        print("Dog")
    elif x%9 == 0 and x%7!= 0:
        print("Cat")
    elif x%9 == 0 and x%7==0:    
        print("DogCat")
    else:(print (x))
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# Dog
# 8
# Cat
# 10
# 11
# 12
# 13
# Dog
# 15
# 16
# 17
# Cat
# 19
# 20
# Dog
# 22
# 23
# 24
# 25
# 26
# Cat
# Dog
# 29
# 30
# 31
# 32
# 33
# 34
# Dog
# Cat
# 37
# 38
# 39
# 40
# 41
# Dog
# 43
# 44
# Cat
# 46
# 47
# 48
# Dog
# 50
# 51
# 52
# 53
# Cat
# 55
# Dog
# 57
# 58
# 59
# 60
# 61
# 62
# DogCat
# 64
# 65
# 66
# 67
# 68
# 69
# Dog
# 71
# Cat
# 73
# 74
# 75
# 76
# Dog
# 78
# 79
# 80
# Cat
# 82
# 83
# Dog
# 85
# 86
# 87
# 88
# 89
# Cat
# Dog
# 92
# 93
# 94
# 95
# 96
# 97
# Dog
# Cat
